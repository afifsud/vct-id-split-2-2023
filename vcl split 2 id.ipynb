# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import plotly.figure_factory as ff
import plotly.graph_objects as go
import plotly.express as px
# %matplotlib inline
import seaborn as sns
import re

# %%
df = pd.read_csv(r"C:\Users\afif\VCL Pacific 2023 Players Dataset - VCL Indonesia Split 2.csv")
df.head()
# Out:
#        Names  Rounds  Kills  Deaths  Assists         ACS        KD     FBSR%  \
# 0     Famouz     543    496     366      127  263.730769  1.355191  0.611765
# 1      Gemma     572    452     392      185  225.407407  1.153061  0.600000
# 2  blaZek1ng     543    448     358      191  235.384615  1.251397  0.578947
# 3      Ray4c     577    416     459      140  219.296296  0.906318  0.412935
# 4     gotten     577    407     399      273  199.000000  1.020050  0.322581
#
#         APR         ADR  ...  Spike Planted  2K  3K  4K  5K  1v1  1v2  1v3  \
# 0  0.233886  263.730769  ...              7  94  37   9   0    3    2    0
# 1  0.323427  225.407407  ...             17  88  24   8   0    4    2    0
# 2  0.351750  235.384615  ...              4  86  30   6   1   12    1    1
# 3  0.242634  219.296296  ...              8  74  28   2   0    3    4    1
# 4  0.473137  199.000000  ...             77  75  21   8   0    8    6    3
#
#    1v4  1v5
# 0    0    0
# 1    0    0
# ...

# %%
df1 = df[['Names', 'ACS']]
df1.head()
df1_desc = df1.sort_values(by=['ACS'], ascending=False)
df1_desc.head()
# Out:
#         Names         ACS
# 0      Famouz  263.730769
# 39      Nakya  239.875000
# 21  k1ngkappa  237.777778
# 2   blaZek1ng  235.384615
# 20     Flynch  233.476190

# %%
plt.figure(figsize=(12,6))
# bar plot with matplotlib
plt.barh('Names', 'ACS',data=df1_desc.head())
plt.xlabel("ACS", size=15)
plt.title("5 Highest ACS Players VCT ID 2023 Split 2", size=18)
plt.gca().invert_yaxis()


plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df2 = df[df['Rounds']>500]
df2
# Out:
#         Names  Rounds  Kills  Deaths  Assists         ACS        KD     FBSR%  \
# 0      Famouz     543    496     366      127  263.730769  1.355191  0.611765
# 1       Gemma     572    452     392      185  225.407407  1.153061  0.600000
# 2   blaZek1ng     543    448     358      191  235.384615  1.251397  0.578947
# 3       Ray4c     577    416     459      140  219.296296  0.906318  0.412935
# 4      gotten     577    407     399      273  199.000000  1.020050  0.322581
# 6      Eeyore     525    395     349       84  211.360000  1.131805  0.485149
# 7       RiseN     577    387     420      200  193.370370  0.921429  0.475410
# 9      ValdyN     554    377     417      198  196.269231  0.904077  0.552381
# 11      Shiro     543    370     344      220  193.000000  1.075581  0.500000
# 16    carrace     536    357     383      140  188.440000  0.932115  0.472973
# 17  asteriskk     572    355     385      311  182.740741  0.922078  0.441860
# ...

# %%
from matplotlib.offsetbox import AnnotationBbox, OffsetImage
from PIL import Image

# %%
fig = plt.figure(figsize = (16,8))
fig,ax = plt.subplots()
fig.set_figheight(10)
fig.set_figwidth(10)

ax.set_xlim(0, 300)
plt.title("Top 5 ACS VCT ID 2023 Split 2")
sns.barplot(x = "ACS", y = "Names",data=df1_desc.head(), palette= "ch:start=.2")

#famouz
famouzlogo = Image.open(r'A:\Downloads\famouz.png') 
imagebox_famouz = OffsetImage(famouzlogo, zoom = 0.3,)
x = [0,1.87]
ab_famouzlogo = AnnotationBbox(imagebox_famouz, x,xybox=(-40,205), boxcoords = 'offset points')
ax.add_artist(ab_famouzlogo)

#nakya
nakyalogo = Image.open(r'A:\Downloads\nakya.png')
imagebox_nakya = OffsetImage(nakyalogo, zoom = 0.3,)
x = [0,1.77]
ab_nakyalogo = AnnotationBbox(imagebox_nakya, x, xybox=(-40,85), boxcoords = 'offset points')
ax.add_artist(ab_nakyalogo)

#k1ngkappa
k1ngkappalogo = Image.open(r'A:\Downloads\k1ngkappa.png')
imagebox_k1ngkappa = OffsetImage(k1ngkappalogo, zoom = 0.3,)
x = [0,1.74]
ab_k1ngkappalogo = AnnotationBbox(imagebox_k1ngkappa, x, xybox=(-40,-27), boxcoords = 'offset points')
ax.add_artist(ab_k1ngkappalogo)

#blazek1ng
blazek1nglogo = Image.open(r'A:\Downloads\blazek1ng.png')
imagebox_blazek1ng = OffsetImage(blazek1nglogo, zoom = 0.30,)
x = [0,1.67]
ab_blazek1nglogo = AnnotationBbox(imagebox_blazek1ng, x, xybox=(-40,-143), boxcoords = 'offset points')
ax.add_artist(ab_blazek1nglogo)

#flynch
flynchlogo = Image.open(r'A:\Downloads\flynch.png')
imagebox_flynch = OffsetImage(flynchlogo, zoom = 0.30,)
x = [0,1.65]
ab_flynchlogo = AnnotationBbox(imagebox_flynch, x, xybox=(-40,-255), boxcoords = 'offset points')
ax.add_artist(ab_flynchlogo)


plt.show()

# %%
#mendefinisikan data ke chart
x = df["Impact"]
y = df["FBSR%"]
z = df["Names"]

#membuat chart nya
fig = plt.figure(figsize=(16,8))
ax =fig.add_subplot(111)

#membuat label tiap data point
for i, label in enumerate(z):
    plt.text(x[i], y[i], label, fontsize=10, ha='right')

plt.scatter(x, y)
plt.xlabel('Impact (Right More Better)')
plt.ylabel('FBSR% (Upper Better)')
plt.grid(True)


plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10)) 

xmin, xmax, ymin, ymax = -0, 0.8, -0, 0.1
ticks_frequency = 0.2


#ini buat garis x sama y nya
ax.set(xlim=(xmin-1, xmax+1), ylim=(ymin-1, ymax+1), aspect='equal')

#buat ketengahin garisnya (make Zero)
ax.spines['bottom'].set_position('zero')
ax.spines['left'].set_position('zero')

#ini buat ilangin garis luar
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

#ini grid
ax.grid(which='both', color='grey', linewidth=1, linestyle='-', alpha=0.2)

 
plt.plot(x, y, 'b')

# %%
df.plot.scatter(x="FBSR%", y="Impact")
# Out:
# <AxesSubplot:xlabel='FBSR%', ylabel='Impact'>
